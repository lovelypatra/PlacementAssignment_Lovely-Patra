# %% [markdown]
# #### Question 4 -
# Write a program to download the data from the link given below and then read the data and convert the into the proper structure and return it as a CSV file.

# %%
import pandas as pd
import requests
response = requests.get('https://data.nasa.gov/resource/y77d-th95.json')
data=response.json()
df = pd.DataFrame(data) #converted the json data in pandas dataframe
df.to_csv("output.csv",index=False) #saved the data in csv format

# %%
df=pd.read_csv('output.csv')

# %%
df
# Out:
#           name     id nametype               recclass      mass  fall  \
# 0       Aachen      1    Valid                     L5      21.0  Fell
# 1       Aarhus      2    Valid                     H6     720.0  Fell
# 2         Abee      6    Valid                    EH4  107000.0  Fell
# 3     Acapulco     10    Valid            Acapulcoite    1914.0  Fell
# 4      Achiras    370    Valid                     L6     780.0  Fell
# ..         ...    ...      ...                    ...       ...   ...
# 995   Tirupati  24009    Valid                     H6     230.0  Fell
# 996    Tissint  54823    Valid  Martian (shergottite)    7000.0  Fell
# 997      Tjabe  24011    Valid                     H6   20000.0  Fell
# 998   Tjerebon  24012    Valid                     L5   16500.0  Fell
# 999  Tomakovka  24019    Valid                    LL6     600.0  Fell
#
#                         year    reclat    reclong  \
# 0    1880-01-01T00:00:00.000  50.77500    6.08333
# ...

# %%
df['point_coordinates']=df['geolocation'].str[34:]

# %%
df['point_coordinates']=df['point_coordinates'].str[:-2]

# %%
df['year']=df['year'].str[:4]

# %%
df=df.drop(['geolocation',':@computed_region_cbhk_fwbd',':@computed_region_nnqa_25f4'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1000 non-null   object
#  1   id                 1000 non-null   int64
#  2   nametype           1000 non-null   object
#  3   recclass           1000 non-null   object
#  4   mass               972 non-null    float64
#  5   fall               1000 non-null   object
#  6   year               999 non-null    object
#  7   reclat             988 non-null    float64
#  8   reclong            988 non-null    float64
#  9   point_coordinates  988 non-null    object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 78.2+ KB

# %%
#df['year'] = pd.to_datetime(df['year'],format='%Y')

# %%
df.fillna(0,inplace=True)

# %%
df['year'] = df['year'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1000 non-null   object
#  1   id                 1000 non-null   int64
#  2   nametype           1000 non-null   object
#  3   recclass           1000 non-null   object
#  4   mass               1000 non-null   float64
#  5   fall               1000 non-null   object
#  6   year               1000 non-null   int32
#  7   reclat             1000 non-null   float64
#  8   reclong            1000 non-null   float64
#  9   point_coordinates  1000 non-null   object
# dtypes: float64(3), int32(1), int64(1), object(5)
# memory usage: 74.3+ KB

# %%
df.to_csv("nasa.csv",index=False) #saved the data in csv format
