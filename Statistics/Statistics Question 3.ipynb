# %% [markdown]
# Q-3. Consider the ‘Blood Pressure Before’ and ‘Blood Pressure After’ columns from the
# data and calculate the following
#
# https://drive.google.com/file/d/1mCjtYHiX--mMUjicuaP2gH3k-SnFxt8Y/view?usp=share_
#
# a. Measure the dispersion in both and interpret the results.
#
# b. Calculate mean and 5% confidence interval and plot it in a graph
#
# c. Calculate the Mean absolute deviation and Standard deviation and interpret the results.
#
# d. Calculate the correlation coefficient and check the significance of it at 1% levelof significance.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import t
from scipy.stats import stats

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#     Patient ID   Blood Pressure Before (mmHg)   Blood Pressure After (mmHg)
# 0            1                            130                           120
# 1            2                            142                           135
# 2            3                            120                           118
# 3            4                            135                           127
# 4            5                            148                           140
# ..         ...                            ...                           ...
# 95          96                            136                           129
# 96          97                            143                           137
# 97          98                            127                           123
# 98          99                            139                           135
# 99         100                            135                           130
#
# [100 rows x 3 columns]

# %%
Blood_Pressure_Before = df[' Blood Pressure Before (mmHg)']
Blood_Pressure_After = df[' Blood Pressure After (mmHg)']

# %%
np.ptp(Blood_Pressure_Before) #ptp calculates range
# Out:
# 28

# %%
np.ptp(Blood_Pressure_After)
# Out:
# 23

# %%
np.mean(Blood_Pressure_Before)# mean is calculated
# Out:
# 133.91

# %%
np.mean(Blood_Pressure_After)
# Out:
# 128.36

# %%
np.var(Blood_Pressure_Before) #var calculates variance
# Out:
# 43.10189999999998

# %%
np.var(Blood_Pressure_After)
# Out:
# 46.97040000000002

# %%
np.std(Blood_Pressure_Before) # standard deviation is calculated
# Out:
# 6.5652037287505385

# %%
np.std(Blood_Pressure_After)
# Out:
# 6.853495458523338

# %% [markdown]
# #### Range: The range is the difference between the maximum and minimum values in a dataset.
#
# Range of ‘Blood Pressure Before’ = Max value - Min value = 148 - 120 = 28 mmHg
#
# Range of ‘Blood Pressure After’ = Max value - Min value = 141 - 118 = 23mmHg
#
# #### Variance:Variance measures the average squared deviation from the mean.
#
# variance = Σ(x - μ)² / n
#
# where x represents each value, μ represents the mean, and n represents the sample size.
#
# Mean of 'Blood Pressure Before' = 133.91 mmHg
#
# Variance of 'Blood Pressure Before' ≈ 43.101 mmHg²
#
# Mean of 'Blood Pressure After' ≈ 128.36 mmHg
#
# Variance of 'Blood Pressure After' ≈ 46.9704 mmHg²
#
# #### Standard Deviation:The standard deviation is the square root of the variance and provides a measure of the dispersion in the dataset.
#
# Standard Deviation of 'Blood Pressure Before' ≈ sqrt(43.101) ≈ 6.56 mmHg
#
# Standard Deviation of 'Blood Pressure After':
# Standard Deviation of 'Blood Pressure After' ≈ sqrt(46.9704) ≈ 6.85 mmHg

# %% [markdown]
# #### a.Interpretation:
# The range indicates the spread between the maximum and minimum values in each dataset. In this case, the range of 'Blood Pressure Before' is 28 mmHg, while the range of 'Blood Pressure After' is 23 mmHg.
#
# The variance and standard deviation provide measures of the average squared deviation from the mean. In the 'Blood Pressure Before' dataset, the variance is approximately 43.101 mmHg², and the standard deviation is approximately 6.56 mmHg. Similarly, in the 'Blood Pressure After' dataset, the variance is approximately 46.9704 mmHg², and the standard deviation is approximately 6.85 mmHg.
#
# A higher range, variance, and standard deviation indicate a greater dispersion or variability in the dataset. Therefore, 'Blood Pressure Before' shows slightly higher dispersion compared to 'Blood Pressure After' as indicated by the larger values of range, variance, and standard deviation.As variance keeps on increasing , spread will be increasing.

# %%
confidence_interval_Bef = t.interval(0.95, 99, loc=133.91, scale=Blood_Pressure_Before.sem())

# %%
confidence_interval_Bef
# Out:
# (132.60075849172767, 135.21924150827232)

# %%
confidence_interval_Aft = t.interval(0.95, 99, loc=128.36, scale=Blood_Pressure_After.sem())

# %%
confidence_interval_Aft
# Out:
# (126.99326697818071, 129.7267330218193)

# %% [markdown]
# #### b.
# Mean of 'Blood Pressure Before' = (130 + 142 + 120 + ... + 135 + 130) / 100 = 133.91 mmHg
#
# Mean of 'Blood Pressure After' ≈ (120 + 135 + 118 + ... + 130 + 130) / 100 ≈ 128.36 mmHgb.

# %% [markdown]
# Confidence Interval:
# To calculate the confidence interval, we need to consider the sample size (n), standard deviation (s), and the desired confidence level.
#
# n = 100
# Standard Error (SE) = σ / sqrt(n)
# Margin of Error (ME) = t-value * SE
# Confidence Interval = Mean ± ME
#
#
# Since the standard deviation of the population is unknown, we'll use the t-distribution for calculating the confidence interval.
#
# confidence level of 95%
#
# degrees of freedom (df) = n - 1 = 100-1 =  99
#
# t-value = 1.984 (using t-distribution table)
#
# #### Confidence Interval for 'Blood Pressure Before':
#
# Standard Error (SE) = 6.56 / sqrt(100) = 0.656 mmHg
#
# Margin of Error (ME) = 1.984 * 0.656 ≈ 1.301 mmHg
#
# Confidence Interval for 'Blood Pressure Before' ≈ 133.91 ± 1.301 mmHg
#
# Confidence Interval = (132.60075849172767, 135.21924150827232)
#
# #### Confidence Interval for 'Blood Pressure After':
#
# Standard Error (SE) ≈ 0.685 mmHg
#
# Margin of Error (ME) ≈ 1.359 mmHg
#
# Confidence Interval for 'Blood Pressure After' ≈ 128.36 ± 1.359 mmHg
#
# Confidence Interval = (126.99326697818071, 129.7267330218193)

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(15, 20),dpi=200)
plt.suptitle('Graph for Blood_Pressure_Before',fontsize = 20, fontweight = 'bold',alpha = 1, y = 1.01)
plt.axhline(133.91, color='r', linestyle='--', label='Mean')
plt.fill_between([0], confidence_interval_Bef[0], confidence_interval_Bef[1], color='gray', alpha=0.3, label='Confidence Interval')
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(15, 20),dpi=200)
plt.suptitle('Graph for Blood_Pressure_After',fontsize = 20, fontweight = 'bold',alpha = 1, y = 1.01)
plt.axhline(128.36, color='r', linestyle='--', label='Mean')
plt.fill_between([0], confidence_interval_Aft[0], confidence_interval_Aft[1], color='gray', alpha=0.3, label='Confidence Interval')
plt.legend()
plt.show()

# %% [markdown]
# #### c.

# %%
Mean_absolute_deviation_bef = np.mean(np.abs(Blood_Pressure_Before - Blood_Pressure_Before.mean()))

# %%
Mean_absolute_deviation_Aft = np.mean(np.abs(Blood_Pressure_After - Blood_Pressure_After.mean()))

# %%
Mean_absolute_deviation_bef
# Out:
# 5.7118

# %%
Mean_absolute_deviation_Aft
# Out:
# 5.9

# %% [markdown]
# Mean absolute deviation(MAD) = Σ|xi - μ| / n
#
# Standard Deviation = sqrt(Σ(xi - μ)² / n)
#
# #### MAD and Standard Deviation for 'Blood Pressure Before':
#
# Mean of 'Blood Pressure Before' = 133.91 mmHg
#
# MAD ≈ 5.7118
#
# Standard Deviation ≈ 6.56 mmHg
#
# #### MAD and Standard Deviation for 'Blood Pressure After':
#
# Mean of 'Blood Pressure After' ≈ 128.36 mmHg
#
# MAD ≈ 5.9 mmHg
#
# Standard Deviation ≈ 6.85 mmHg
#
# Interpretation:
# MAD represents the average absolute difference of each data point from the mean. For 'Blood Pressure Before,' the MAD is approximately 5.7118 mmHg, and for 'Blood Pressure After,' the MAD is approximately 5.9 mmHg. These values indicate the average deviation from the mean value, with higher MAD values indicating greater dispersion or variability.
#
# Standard Deviation measures the average squared difference of each data point from the mean. For 'Blood Pressure Before,' the Standard Deviation is approximately 6.56 mmHg, and for 'Blood Pressure After,' it is approximately 6.85 mmHg. A higher Standard Deviation implies a larger spread or dispersion of data points from the mean.

# %% [markdown]
# #### d. Correlation Coefficient and Significance:
#
#
# Correlation Coefficient:
# Using the formula for the Pearson correlation coefficient:
#
# r = cov(x,y)/ (σx* σy)
#
# Where x and y represent the values in the 'Blood Pressure Before' and 'Blood Pressure After' columns, and  σ represents the standard deviation.
#
# correlation_coefficient = 1

# %%
correlation_coefficient, p_value = stats.pearsonr(Blood_Pressure_Before, Blood_Pressure_Before)

# %%
correlation_coefficient
# Out:
# 1.0

# %%
p_value
# Out:
# 0.0

# %%
alpha = 0.01
if p_value < alpha:
    print("The correlation is significant at the 1% level.")
else:
    print("The correlation is not significant at the 1% level.")
# Out:
# The correlation is significant at the 1% level.
